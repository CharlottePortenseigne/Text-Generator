# %% [markdown]
# # PROJECT FINAL #

# %%
# import librairy
import tensorflow as tf
import string
import requests
import numpy as np
from keras.models import Sequential, load_model
from keras.layers import Dense, Embedding, LSTM, Dropout
from keras.utils import to_categorical
from random import randint
import re

# %% [markdown]
# ## Extrat Data

# %%
# import corpus
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg as gut

#print(gut.fileids())
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/charlotteportenseigne/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
# get text
emma_text = nltk.corpus.gutenberg.raw('austen-emma.txt')
emma_text = emma_text[28:-2]

persuasion_text = nltk.corpus.gutenberg.raw('austen-persuasion.txt')
persuasion_text = persuasion_text[35:-6]

sense_text = nltk.corpus.gutenberg.raw('austen-sense.txt')
sense_text = sense_text[45:-3]

bible_text = nltk.corpus.gutenberg.raw('bible-kjv.txt')
bible_text = bible_text[24:-3]

blake_text = nltk.corpus.gutenberg.raw('blake-poems.txt')
blake_text = blake_text[33:-3]

bryant_text = nltk.corpus.gutenberg.raw('bryant-stories.txt')
bryant_text = bryant_text[61:-3]

busterbrown_text = nltk.corpus.gutenberg.raw('burgess-busterbrown.txt')
busterbrown_text = busterbrown_text[63:-4]

alice_text = nltk.corpus.gutenberg.raw('carroll-alice.txt')
alice_text = alice_text[58:]

ball_text = nltk.corpus.gutenberg.raw('chesterton-ball.txt')
ball_text = ball_text[51:-67]

brown_text = nltk.corpus.gutenberg.raw('chesterton-brown.txt')
brown_text = brown_text[56:-2]

thursday_text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
thursday_text = thursday_text[53:-2]

parents_text = nltk.corpus.gutenberg.raw('edgeworth-parents.txt')
parents_text = parents_text[50:-2]

moby_dick_text = nltk.corpus.gutenberg.raw('melville-moby_dick.txt')
moby_dick_text = moby_dick_text[41:-2]

paradise_text = nltk.corpus.gutenberg.raw('milton-paradise.txt')
paradise_text = paradise_text[41:-15]

caesar_text = nltk.corpus.gutenberg.raw('shakespeare-caesar.txt')
caesar_text = caesar_text[62:-3]

hamlet_text = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')
hamlet_text = hamlet_text[55:]

macbeth_text = nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')
macbeth_text = macbeth_text[56:]

leaves_text = nltk.corpus.gutenberg.raw('whitman-leaves.txt')
leaves_text = leaves_text[41:-2]

# %% [markdown]
# ## Cleaning Data + Sentences to list of words

# %%
#clean function
def clean_text(doc):
    tokens = doc.split()
    table = str.maketrans('', '', string.punctuation) # take off punctuation
    tokens = [w.translate(table) for w in tokens]
    tokens = [ word for word in tokens if word.isalpha()] # select only alphannumeric letter
    tokens = [word.lower() for word in tokens] # converte letter into lower case
    return tokens

# %%
emma_tokens = clean_text(emma_text)
persuasion_tokens = clean_text(persuasion_text)
sense_tokens = clean_text(sense_text)
bible_tokens = clean_text(bible_text) 
blake_tokens = clean_text(blake_text) 
bryant_tokens = clean_text(bryant_text) 
busterbrown_tokens = clean_text(busterbrown_text)
alice_tokens = clean_text(alice_text)
ball_tokens = clean_text(ball_text) 
brown_tokens = clean_text(brown_text)
thursday_tokens = clean_text(thursday_text)
parents_tokens = clean_text(parents_text)
moby_dick_tokens = clean_text(moby_dick_text)
paradise_tokens = clean_text(paradise_text)
caesar_tokens = clean_text(caesar_text) 
hamlet_tokens = clean_text(hamlet_text)
macbeth_tokens = clean_text(macbeth_text)
leaves_tokens = clean_text(leaves_text)
#print(emma_tokens[:50])

# %%
# merge lists together
gutemberg_tokens = emma_tokens + persuasion_tokens + sense_tokens + bible_tokens + blake_tokens + bryant_tokens + busterbrown_tokens + alice_tokens + ball_tokens + brown_tokens + thursday_tokens + parents_tokens + moby_dick_tokens + paradise_tokens + caesar_tokens + hamlet_tokens + macbeth_tokens + leaves_tokens

# %%
# number of words
n_words = len(gutemberg_tokens)
unique_words = len(set(gutemberg_tokens))
print(f'Total words : ', n_words)
print(f'Unique words : ', unique_words)
# Out:
# Total words :  2102324
# Unique words :  53322

# %% [markdown]
# ## Prepare for train model ##

# %%
# take 50 words and predict the 51 words
lenght = 50 + 1
lines = []

for i in range(lenght, len(gutemberg_tokens)):
    seq = gutemberg_tokens[i-lenght:i]
    line = ' '.join(seq)
    lines.append(line)
    if i > 200000:  # we only do 200,000 words because of the RAM
        break

# %%
import pickle
# saving
with open('lines.pickle', 'wb') as handle:
    pickle.dump(lines, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('lines.pickle', 'rb') as handle:
    lines = pickle.load(handle)
# print(len(lines))

# %% [markdown]
# ## Build LSTM Model and Prepare `x` and `y`

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# tokenize sentence
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines) # kind of words embedding into integer
sequences = tokenizer.texts_to_sequences(lines)

# %%
import pickle

# saving
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
sequences = np.array(sequences)
X, y = sequences[:, :-1], sequences[:, -1] # select all the column except the last one, select only the last column

# %%
X[0] # vector, kind of word embedding, the digit represent a word
# Out:
# array([ 2415,     6,   351,     6,    43,   112,   491,   754,     3,
#          960,    22,     5,   528,   157,     3,   183,   777,   139,
#            2,  3862,    94,     4,     1,   242,  2162,     4,  2759,
#            3,    14,   585,   919, 10474,   274,    11,     1,   269,
#           22,    24,    70,     2,   817,    53, 10472,     8,    10,
#            7,     1,  1949,     4,     1])

# %%
# index for each word
tokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'and': 3,
#  'of': 4,
#  'a': 5,
#  'i': 6,
#  'was': 7,
#  'her': 8,
#  'it': 9,
#  'she': 10,
#  'in': 11,
#  'not': 12,
#  'be': 13,
#  'had': 14,
#  'he': 15,
#  'that': 16,
#  'you': 17,
#  'as': 18,
#  'for': 19,
#  'have': 20,
#  'but': 21,
#  'with': 22,
#  'his': 23,
#  'very': 24,
#  'is': 25,
#  'at': 26,
#  'mr': 27,
#  'so': 28,
#  'all': 29,
#  'could': 30,
#  'been': 31,
#  'would': 32,
#  'him': 33,
#  'on': 34,
#  'no': 35,
#  'were': 36,
#  'mrs': 37,
#  'by': 38,
#  'my': 39,
#  'they': 40,
#  'any': 41,
#  'which': 42,
#  'emma': 43,
#  'do': 44,
#  'from': 45,
#  'must': 46,
#  'there': 47,
#  'miss': 48,
#  'this': 49,
#  'will': 50,
#  'more': 51,
#  'me': 52,
#  'or': 53,
#  'what': 54,
#  'an': 55,
#  'much': 56,
#  'such': 57,
#  'them': 58,
#  'if': 59,
#  'than': 60,
#  'said': 61,
#  'one': 62,
#  'are': 63,
#  'being': 64,
#  'every': 65,
#  'when': 66,
#  'their': 67,
#  'am': 68,
#  'should': 69,
#  'little': 70,
#  'think': 71,
#  'only': 72,
#  'never': 73,
#  'well': 74,
#  'we': 75,
#  'did': 76,
#  'how': 77,
#  'might': 78,
#  'thing': 79,
#  'your': 80,
#  'who': 81,
#  'own': 82,
#  'good': 83,
#  'harriet': 84,
#  'weston': 85,
#  'now': 86,
#  'know': 87,
#  'say': 88,
#  'herself': 89,
#  'time': 90,
#  'great': 91,
#  'quite': 92,
#  'knightley': 93,
#  'some': 94,
#  'can': 95,
#  'elton': 96,
#  'most': 97,
#  'about': 98,
#  'always': 99,
#  'nothing': 100,
#  'before': 101,
#  'soon': 102,
#  'too': 103,
#  'other': 104,
#  'has': 105,
#  'jane': 106,
#  'thought': 107,
#  'without': 108,
#  'first': 109,
#  'again': 110,
#  'dear': 111,
#  'woodhouse': 112,
#  'man': 113,
#  'see': 114,
#  'made': 115,
#  'may': 116,
#  'out': 117,
#  'up': 118,
#  'young': 119,
#  'though': 120,
#  'two': 121,
#  'shall': 122,
#  'sure': 123,
#  'like': 124,
#  'ever': 125,
#  'into': 126,
#  'better': 127,
#  'anne': 128,
#  'after': 129,
#  'father': 130,
#  'come': 131,
#  'fairfax': 132,
#  'just': 133,
#  'indeed': 134,
#  'having': 135,
#  'then': 136,
#  'make': 137,
#  'give': 138,
#  'seemed': 139,
#  'oh': 140,
#  'upon': 141,
#  'frank': 142,
#  'long': 143,
#  'churchill': 144,
#  'way': 145,
#  'go': 146,
#  'himself': 147,
#  'day': 148,
#  'done': 149,
#  'captain': 150,
#  'friend': 151,
#  'many': 152,
#  'away': 153,
#  'rather': 154,
#  'while': 155,
#  'us': 156,
#  'home': 157,
#  'over': 158,
#  'however': 159,
#  'really': 160,
#  'poor': 161,
#  'body': 162,
#  'here': 163,
#  'its': 164,
#  'even': 165,
#  'house': 166,
#  'hope': 167,
#  'wish': 168,
#  'cannot': 169,
#  'mind': 170,
#  'lady': 171,
#  'enough': 172,
#  'going': 173,
#  'came': 174,
#  'hartfield': 175,
#  'felt': 176,
#  'still': 177,
#  'last': 178,
#  'take': 179,
#  'heard': 180,
#  'same': 181,
#  'few': 182,
#  'happy': 183,
#  'another': 184,
#  'does': 185,
#  'sir': 186,
#  'found': 187,
#  'off': 188,
#  'feelings': 189,
#  'woman': 190,
#  'look': 191,
#  'yet': 192,
#  'something': 193,
#  'pleasure': 194,
#  'moment': 195,
#  'our': 196,
#  'love': 197,
#  'sort': 198,
#  'half': 199,
#  'till': 200,
#  'morning': 201,
#  'wentworth': 202,
#  'highbury': 203,
#  'knew': 204,
#  'hear': 205,
#  'saw': 206,
#  'bates': 207,
#  'believe': 208,
#  'ought': 209,
#  'party': 210,
#  'almost': 211,
#  'place': 212,
#  'once': 213,
#  'deal': 214,
#  'those': 215,
#  'where': 216,
#  'certainly': 217,
#  'idea': 218,
#  'perhaps': 219,
#  'family': 220,
#  'together': 221,
#  'feel': 222,
#  'doubt': 223,
#  'both': 224,
#  'evening': 225,
#  'people': 226,
#  'subject': 227,
#  'possible': 228,
#  'yes': 229,
#  'charles': 230,
#  'present': 231,
#  'speak': 232,
#  'often': 233,
#  'down': 234,
#  'gone': 235,
#  'looked': 236,
#  'coming': 237,
#  'myself': 238,
#  'room': 239,
#  'right': 240,
#  'seen': 241,
#  'best': 242,
#  'old': 243,
#  'friends': 244,
#  'letter': 245,
#  'least': 246,
#  'want': 247,
#  'visit': 248,
#  'word': 249,
#  'back': 250,
#  'given': 251,
#  'cried': 252,
#  'between': 253,
#  'these': 254,
#  'manner': 255,
#  'let': 256,
#  'left': 257,
#  'life': 258,
#  'suppose': 259,
#  'told': 260,
#  'whole': 261,
#  'hardly': 262,
#  'wanted': 263,
#  'three': 264,
#  'else': 265,
#  'side': 266,
#  'part': 267,
#  'get': 268,
#  'world': 269,
#  'happiness': 270,
#  'whom': 271,
#  'randalls': 272,
#  'perfectly': 273,
#  'years': 274,
#  'hour': 275,
#  'spirits': 276,
#  'john': 277,
#  'far': 278,
#  'tell': 279,
#  'replied': 280,
#  'wife': 281,
#  'since': 282,
#  'harriets': 283,
#  'eltons': 284,
#  'short': 285,
#  'either': 286,
#  'under': 287,
#  'find': 288,
#  'next': 289,
#  'kind': 290,
#  'acquaintance': 291,
#  'obliged': 292,
#  'set': 293,
#  'able': 294,
#  'general': 295,
#  'mary': 296,
#  'opinion': 297,
#  'others': 298,
#  'known': 299,
#  'towards': 300,
#  'change': 301,
#  'nobody': 302,
#  'immediately': 303,
#  'less': 304,
#  'heart': 305,
#  'children': 306,
#  'talked': 307,
#  'pretty': 308,
#  'therefore': 309,
#  'began': 310,
#  'emmas': 311,
#  'name': 312,
#  'put': 313,
#  'leave': 314,
#  'course': 315,
#  'nor': 316,
#  'whether': 317,
#  'looking': 318,
#  'person': 319,
#  'thinking': 320,
#  'through': 321,
#  'walk': 322,
#  'carriage': 323,
#  'account': 324,
#  'ready': 325,
#  'things': 326,
#  'answer': 327,
#  'extremely': 328,
#  'situation': 329,
#  'true': 330,
#  'among': 331,
#  'comfort': 332,
#  'understand': 333,
#  'assure': 334,
#  'mother': 335,
#  'brought': 336,
#  'days': 337,
#  'perry': 338,
#  'taken': 339,
#  'state': 340,
#  'near': 341,
#  'passed': 342,
#  'martin': 343,
#  'walter': 344,
#  'glad': 345,
#  'afraid': 346,
#  'attention': 347,
#  'return': 348,
#  'longer': 349,
#  'degree': 350,
#  'chapter': 351,
#  'sister': 352,
#  'marry': 353,
#  'equal': 354,
#  'each': 355,
#  'brother': 356,
#  'feeling': 357,
#  'gave': 358,
#  'bad': 359,
#  'seeing': 360,
#  'manners': 361,
#  'talk': 362,
#  'end': 363,
#  'character': 364,
#  'wished': 365,
#  'dare': 366,
#  'beyond': 367,
#  'business': 368,
#  'agreeable': 369,
#  'care': 370,
#  'smith': 371,
#  'eyes': 372,
#  'sorry': 373,
#  'making': 374,
#  'talking': 375,
#  'elliot': 376,
#  'doing': 377,
#  'bear': 378,
#  'because': 379,
#  'sense': 380,
#  'interest': 381,
#  'usual': 382,
#  'natural': 383,
#  'rest': 384,
#  'afterwards': 385,
#  'walked': 386,
#  'mean': 387,
#  'yourself': 388,
#  'full': 389,
#  'hand': 390,
#  'went': 391,
#  'imagine': 392,
#  'stay': 393,
#  'against': 394,
#  'superior': 395,
#  'minutes': 396,
#  'musgrove': 397,
#  'saying': 398,
#  'took': 399,
#  'ladies': 400,
#  'themselves': 401,
#  'louisa': 402,
#  'early': 403,
#  'married': 404,
#  'exactly': 405,
#  'aunt': 406,
#  'giving': 407,
#  'westons': 408,
#  'voice': 409,
#  'remember': 410,
#  'likely': 411,
#  'strong': 412,
#  'point': 413,
#  'uppercross': 414,
#  'means': 415,
#  'society': 416,
#  'used': 417,
#  'satisfied': 418,
#  'child': 419,
#  'pleased': 420,
#  'attachment': 421,
#  'called': 422,
#  'appeared': 423,
#  'spoke': 424,
#  'london': 425,
#  'walking': 426,
#  'directly': 427,
#  'ill': 428,
#  'read': 429,
#  'dinner': 430,
#  'conversation': 431,
#  'cold': 432,
#  'head': 433,
#  'believed': 434,
#  'met': 435,
#  'why': 436,
#  'fathers': 437,
#  'fine': 438,
#  'wonder': 439,
#  'speaking': 440,
#  'words': 441,
#  'affection': 442,
#  'particularly': 443,
#  'settled': 444,
#  'isabella': 445,
#  'daughter': 446,
#  'help': 447,
#  'received': 448,
#  'whose': 449,
#  'beginning': 450,
#  'new': 451,
#  'respect': 452,
#  'air': 453,
#  'kellynch': 454,
#  'russell': 455,
#  'real': 456,
#  'already': 457,
#  'girl': 458,
#  'hoped': 459,
#  'regard': 460,
#  'sometimes': 461,
#  'need': 462,
#  'son': 463,
#  'musgroves': 464,
#  'henrietta': 465,
#  'returned': 466,
#  'call': 467,
#  'allow': 468,
#  'proper': 469,
#  'use': 470,
#  'reason': 471,
#  'meeting': 472,
#  'got': 473,
#  'question': 474,
#  'meant': 475,
#  'different': 476,
#  'expected': 477,
#  'object': 478,
#  'cole': 479,
#  'consequence': 480,
#  'sit': 481,
#  'fortune': 482,
#  'entirely': 483,
#  'door': 484,
#  'ah': 485,
#  'forward': 486,
#  'particular': 487,
#  'country': 488,
#  'farther': 489,
#  'asked': 490,
#  'handsome': 491,
#  'excellent': 492,
#  'allowed': 493,
#  'power': 494,
#  'husband': 495,
#  'neither': 496,
#  'determined': 497,
#  'taste': 498,
#  'added': 499,
#  'fond': 500,
#  'pleasant': 501,
#  'company': 502,
#  'round': 503,
#  'gentleman': 504,
#  'open': 505,
#  'continued': 506,
#  'night': 507,
#  'face': 508,
#  'year': 509,
#  'bring': 510,
#  'hours': 511,
#  'health': 512,
#  'men': 513,
#  'bath': 514,
#  'kindness': 515,
#  'large': 516,
#  'necessary': 517,
#  'ask': 518,
#  'churchills': 519,
#  'nature': 520,
#  'donwell': 521,
#  'wrong': 522,
#  'thank': 523,
#  'weather': 524,
#  'smile': 525,
#  'letters': 526,
#  'admiral': 527,
#  'comfortable': 528,
#  'thoughts': 529,
#  'sent': 530,
#  'taking': 531,
#  'sitting': 532,
#  'campbell': 533,
#  'sat': 534,
#  'five': 535,
#  'meet': 536,
#  'impossible': 537,
#  'keep': 538,
#  'pain': 539,
#  'common': 540,
#  'circumstances': 541,
#  'decided': 542,
#  'convinced': 543,
#  'case': 544,
#  'seem': 545,
#  'probably': 546,
#  'within': 547,
#  'consider': 548,
#  'marriage': 549,
#  'perfect': 550,
#  'creature': 551,
#  'engaged': 552,
#  'appearance': 553,
#  'months': 554,
#  'serious': 555,
#  'woodhouses': 556,
#  'temper': 557,
#  'circumstance': 558,
#  'small': 559,
#  'delightful': 560,
#  'truth': 561,
#  'acquainted': 562,
#  'knightleys': 563,
#  'persuaded': 564,
#  'danger': 565,
#  'evil': 566,
#  'amiable': 567,
#  'advantage': 568,
#  'hearing': 569,
#  'turned': 570,
#  'matter': 571,
#  'elizabeth': 572,
#  'worse': 573,
#  'appear': 574,
#  'spoken': 575,
#  'followed': 576,
#  'resolution': 577,
#  'supposed': 578,
#  'second': 579,
#  'week': 580,
#  'fancy': 581,
#  'anxious': 582,
#  'wanting': 583,
#  'colonel': 584,
#  'lived': 585,
#  'none': 586,
#  'warm': 587,
#  'influence': 588,
#  'delighted': 589,
#  'knowledge': 590,
#  'notice': 591,
#  'dixon': 592,
#  'lyme': 593,
#  'taylor': 594,
#  'gratitude': 595,
#  'difference': 596,
#  'papa': 597,
#  'times': 598,
#  'please': 599,
#  'knows': 600,
#  'alone': 601,
#  'fair': 602,
#  'meaning': 603,
#  'praise': 604,
#  'instead': 605,
#  'worth': 606,
#  'news': 607,
#  'match': 608,
#  'cheerful': 609,
#  'pass': 610,
#  'enscombe': 611,
#  'greater': 612,
#  'favour': 613,
#  'high': 614,
#  'completely': 615,
#  'turn': 616,
#  'absolutely': 617,
#  'ashamed': 618,
#  'engagement': 619,
#  'dancing': 620,
#  'beauty': 621,
#  'sisters': 622,
#  'friendship': 623,
#  'begin': 624,
#  'looks': 625,
#  'four': 626,
#  'hands': 627,
#  'considered': 628,
#  'occasion': 629,
#  'surprize': 630,
#  'goddards': 631,
#  'interesting': 632,
#  'actually': 633,
#  'difficulty': 634,
#  'eye': 635,
#  'easy': 636,
#  'mentioned': 637,
#  'greatest': 638,
#  'understanding': 639,
#  'view': 640,
#  'curiosity': 641,
#  'women': 642,
#  'sight': 643,
#  'style': 644,
#  'agreed': 645,
#  'certain': 646,
#  'tone': 647,
#  'conduct': 648,
#  'campbells': 649,
#  'hall': 650,
#  'ago': 651,
#  'highly': 652,
#  'companion': 653,
#  'town': 654,
#  'pity': 655,
#  'sensible': 656,
#  'except': 657,
#  'vain': 658,
#  'obliging': 659,
#  'admiration': 660,
#  'plan': 661,
#  'yesterday': 662,
#  'ten': 663,
#  'hers': 664,
#  'forget': 665,
#  'past': 666,
#  'aware': 667,
#  'loved': 668,
#  'horses': 669,
#  'especially': 670,
#  'fact': 671,
#  'merely': 672,
#  'compliment': 673,
#  'generally': 674,
#  'understood': 675,
#  'says': 676,
#  'tried': 677,
#  'kept': 678,
#  'silent': 679,
#  'excuse': 680,
#  'charming': 681,
#  'honour': 682,
#  'attentions': 683,
#  'turning': 684,
#  'trying': 685,
#  'hill': 686,
#  'anything': 687,
#  'living': 688,
#  'age': 689,
#  'useful': 690,
#  'whenever': 691,
#  'late': 692,
#  'observed': 693,
#  'moments': 694,
#  'quiet': 695,
#  'happened': 696,
#  'struck': 697,
#  'extraordinary': 698,
#  'besides': 699,
#  'claims': 700,
#  'secret': 701,
#  'also': 702,
#  'ball': 703,
#  'fairfaxs': 704,
#  'maple': 705,
#  'grove': 706,
#  'benwick': 707,
#  'daughters': 708,
#  'satisfaction': 709,
#  'knowing': 710,
#  'pray': 711,
#  'shew': 712,
#  'favourite': 713,
#  'surprized': 714,
#  'due': 715,
#  'former': 716,
#  'proof': 717,
#  'bodys': 718,
#  'elegant': 719,
#  'sake': 720,
#  'smiling': 721,
#  'judge': 722,
#  'hint': 723,
#  'table': 724,
#  'sea': 725,
#  'join': 726,
#  'harville': 727,
#  'attached': 728,
#  'judgment': 729,
#  'lost': 730,
#  'scheme': 731,
#  'pay': 732,
#  'comes': 733,
#  'depend': 734,
#  'today': 735,
#  'service': 736,
#  'spirit': 737,
#  'became': 738,
#  'regret': 739,
#  'inclination': 740,
#  'scarcely': 741,
#  'invitation': 742,
#  'mine': 743,
#  'summer': 744,
#  'robert': 745,
#  'seems': 746,
#  'fixed': 747,
#  'entered': 748,
#  'low': 749,
#  'smallest': 750,
#  'finding': 751,
#  'caught': 752,
#  'resolved': 753,
#  'clever': 754,
#  'loss': 755,
#  'event': 756,
#  'work': 757,
#  'spite': 758,
#  'sad': 759,
#  'spent': 760,
#  'distance': 761,
#  'answered': 762,
#  'wishes': 763,
#  'pleasing': 764,
#  'enjoyment': 765,
#  'purpose': 766,
#  'send': 767,
#  'justice': 768,
#  'growing': 769,
#  'duty': 770,
#  'consideration': 771,
#  'tired': 772,
#  'remain': 773,
#  'behaviour': 774,
#  'shepherd': 775,
#  'annes': 776,
#  'disposition': 777,
#  'considering': 778,
#  'miles': 779,
#  'live': 780,
#  'odd': 781,
#  'observe': 782,
#  'beautiful': 783,
#  'pride': 784,
#  'altogether': 785,
#  'weeks': 786,
#  'note': 787,
#  'lately': 788,
#  'martins': 789,
#  'led': 790,
#  'gentlemen': 791,
#  'quarter': 792,
#  'try': 793,
#  'music': 794,
#  'eager': 795,
#  'wait': 796,
#  'behind': 797,
#  'write': 798,
#  'silence': 799,
#  'cottage': 800,
#  'coles': 801,
#  'crown': 802,
#  'croft': 803,
#  'hayter': 804,
#  'disposed': 805,
#  'sweet': 806,
#  'fortunate': 807,
#  'goddard': 808,
#  'quick': 809,
#  'confidence': 810,
#  'anxiety': 811,
#  'consciousness': 812,
#  'standing': 813,
#  'safe': 814,
#  'severe': 815,
#  'reached': 816,
#  'distress': 817,
#  'intimacy': 818,
#  'liked': 819,
#  'promise': 820,
#  'marrying': 821,
#  'hurry': 822,
#  'lose': 823,
#  'thinks': 824,
#  'spend': 825,
#  'nonsense': 826,
#  'respectable': 827,
#  'complete': 828,
#  'mention': 829,
#  'couple': 830,
#  'history': 831,
#  'recommend': 832,
#  'speech': 833,
#  'chance': 834,
#  'tomorrow': 835,
#  'imagined': 836,
#  'hopes': 837,
#  'calling': 838,
#  'neighbourhood': 839,
#  'agitation': 840,
#  'wishing': 841,
#  'telling': 842,
#  'period': 843,
#  'dine': 844,
#  'sigh': 845,
#  'happily': 846,
#  'considerable': 847,
#  'guess': 848,
#  'safely': 849,
#  'chuse': 850,
#  'connexion': 851,
#  'desirable': 852,
#  'written': 853,
#  'abbey': 854,
#  'parties': 855,
#  'reasonable': 856,
#  'credit': 857,
#  'strength': 858,
#  'share': 859,
#  'information': 860,
#  'expect': 861,
#  'mistaken': 862,
#  'countenance': 863,
#  'stand': 864,
#  'occurred': 865,
#  'effect': 866,
#  'getting': 867,
#  'listen': 868,
#  'promised': 869,
#  'fully': 870,
#  'rooms': 871,
#  'instrument': 872,
#  'box': 873,
#  'crofts': 874,
#  'suffering': 875,
#  'required': 876,
#  'tea': 877,
#  'placed': 878,
#  'breakfast': 879,
#  'suspect': 880,
#  'reflection': 881,
#  'forgotten': 882,
#  'proved': 883,
#  'whatever': 884,
#  'single': 885,
#  'become': 886,
#  'worst': 887,
#  'youth': 888,
#  'goodwill': 889,
#  'plain': 890,
#  'close': 891,
#  'inferior': 892,
#  'indifferent': 893,
#  'shewed': 894,
#  'picture': 895,
#  'order': 896,
#  'blush': 897,
#  'opportunity': 898,
#  'remained': 899,
#  'makes': 900,
#  'attempt': 901,
#  'warmly': 902,
#  'delight': 903,
#  'henry': 904,
#  'trouble': 905,
#  'listened': 906,
#  'returning': 907,
#  'presently': 908,
#  'views': 909,
#  'staying': 910,
#  'otherwise': 911,
#  'passing': 912,
#  'batess': 913,
#  'spring': 914,
#  'suspicion': 915,
#  'future': 916,
#  'dance': 917,
#  'pianoforte': 918,
#  'nearly': 919,
#  'disagreeable': 920,
#  'fault': 921,
#  'rational': 922,
#  'thoroughly': 923,
#  'rain': 924,
#  'persons': 925,
#  'important': 926,
#  'occupied': 927,
#  'boy': 928,
#  'mothers': 929,
#  'unhappy': 930,
#  'girls': 931,
#  'difficulties': 932,
#  'stood': 933,
#  'run': 934,
#  'winter': 935,
#  'form': 936,
#  'busy': 937,
#  'conviction': 938,
#  'amused': 939,
#  'approbation': 940,
#  'mere': 941,
#  'waiting': 942,
#  'itself': 943,
#  'persuade': 944,
#  'equally': 945,
#  'likeness': 946,
#  'thats': 947,
#  'wrote': 948,
#  'offer': 949,
#  'reply': 950,
#  'angry': 951,
#  'mans': 952,
#  'ease': 953,
#  'joined': 954,
#  'instantly': 955,
#  'excepting': 956,
#  'alarm': 957,
#  'william': 958,
#  'terms': 959,
#  'rich': 960,
#  'gentle': 961,
#  'anywhere': 962,
#  'absence': 963,
#  'joy': 964,
#  'uncle': 965,
#  'ones': 966,
#  'circle': 967,
#  'compliments': 968,
#  'neighbours': 969,
#  'regular': 970,
#  'deserve': 971,
#  'window': 972,
#  'arrangement': 973,
#  'during': 974,
#  'value': 975,
#  'sudden': 976,
#  'lines': 977,
#  'minute': 978,
#  'disappointment': 979,
#  'intended': 980,
#  'delay': 981,
#  'move': 982,
#  'recollect': 983,
#  'play': 984,
#  'dreadful': 985,
#  'disappointed': 986,
#  'indifference': 987,
#  'paid': 988,
#  'escape': 989,
#  'suffer': 990,
#  'declare': 991,
#  'intercourse': 992,
#  'ways': 993,
#  'smiled': 994,
#  'james': 995,
#  'ideas': 996,
#  'possibly': 997,
#  'dearest': 998,
#  'amusement': 999,
#  'worthy': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index) +1

# %%
y = to_categorical(y, num_classes=vocab_size)

# %%
seq_length = X.shape[1]

# %%
# saving
import pickle
with open('seq_length.pickle', 'wb') as handle:
    pickle.dump(seq_length, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('seq_length.pickle', 'rb') as handle:
    seq_length = pickle.load(handle)

# %% [markdown]
# ## LSTM Model ##

# %%
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dropout(0.2))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(vocab_size, activation = 'softmax'))
#model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 50)            523750
# _________________________________________________________________
# lstm (LSTM)                  (None, 50, 100)           60400
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 10475)             1057975
# =================================================================
# Total params: 1,732,625
# Trainable params: 1,732,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %%
# train
model.fit(X, y, batch_size = 100, epochs = 4) # We can change the batch and the epoch
# epochs 25 takes 2h30, for /199951 and 100 epochs 0,46 accurancy
# Out:
# Epoch 1/4
# 2000/2000 [==============================] - 332s 166ms/step - loss: 4.9092 - accuracy: 0.1430
# Epoch 2/4
# 2000/2000 [==============================] - 296s 148ms/step - loss: 4.8436 - accuracy: 0.1472
# Epoch 3/4
# 2000/2000 [==============================] - 303s 151ms/step - loss: 4.7979 - accuracy: 0.1492
# Epoch 4/4
# 2000/2000 [==============================] - 366s 183ms/step - loss: 4.7579 - accuracy: 0.1510

# %%
# batch_size = 100, epochs = 4 - accuracy 0.1279, time: 22min 40
# batch_size = 100, epochs = 5 - accuracy 0.1362 , time:32min 11
# batch_size = 150, epochs = 5 - accuracy 0.1278 , time:30min 28
# bach_size = 50, epochs = 5 - accuracy 0.1255, time: 40m
# batch_size = 100, epochs = 10 - accuracy: 0.1565 - 59min
# batch_size = 200, epochs = 10 - accuracy: 0.1440 - 59min
# batch_size = 250, epochs = 20 - accuracy: 0.1758 - 95min
# batch_size = 100, epochs = 20 - accuracy: 0.1721 - 117min

# %%
#import joblib
from keras.models import load_model

#joblib.dump(gutemberg_tokens, "texts_model.joblib")
model.save("prediction_model.h5")

# %% [markdown]
# ## Predict text ##

# %%
# function to predict text
def generate_text_seq(model, tokenizer, text_seq_length, seed_text, n_words):
    text = []

    for _ in range(n_words): # how many words you want to generate
        encoded = tokenizer.texts_to_sequences([seed_text])[0]
        encoded = pad_sequences([encoded], maxlen = text_seq_length, truncating = 'pre')

        y_predict = model.predict_classes(encoded) # return the interger value of the word

        predicted_word = ''
        for word, index in tokenizer.word_index.items(): # find the word by the integer word
            if index == y_predict:
                predicted_word = word
                break
        seed_text = seed_text + ' ' + predicted_word
        text.append(predicted_word)
    return ' '.join(text)

# %%
# predict sentence
# generate_text_seq(model, tokenizer, seq_length, seed_text = lines[12343], n_words)
generate_text_seq(model, tokenizer, seq_length, lines[0], 3)
# Out:
# 'days of the'

# %% [markdown]
# ## Test the model ##

# %%
lines[3]
# Out:
# 'i emma woodhouse handsome clever and rich with a comfortable home and happy disposition seemed to unite some of the best blessings of existence and had lived nearly twentyone years in the world with very little to distress or vex her she was the youngest of the two daughters of a'

# %%
# compare part of speech
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(lines[3][-14:])
for token in doc:
    POS = token.pos_
    print(token.text, token.pos_)

# predict text
pred_doc = nlp(generate_text_seq(model, tokenizer, seq_length, lines[0], 3))
for token in pred_doc:
    pred_POS = token.pos_
    print(token.text, token.pos_)

if POS == pred_POS:
    print("They have the same Part Of Speech")
else:
    print("They have different Part Of Speech")
# Out:
# daughters NOUN
# of ADP
# a PRON
# days NOUN
# of ADP
# the PRON
# They have the same Part Of Speech

# %% [markdown]
# ## Visualization of the prediction ##

# %%
# visualization of the actual sentence and the sentence with the predicted words
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")
# sentence with the predicted words
pred_text = lines[0]+ ' ' + generate_text_seq(model, tokenizer, seq_length, lines[0], 3)
pred_doc = nlp(pred_text)
pred_sentence_spans = list(pred_doc.sents)
displacy.render(pred_sentence_spans, style="dep")

# actual sentence in the text
text = lines[0] + ' ' + lines[3][-14:]
doc = nlp(text)
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8b6a097ee0904172b2290922e5669a47-0" class="displacy" width="7750" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">volume</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">chapter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">emma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">woodhouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">handsome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">clever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">rich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">comfortable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">home</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">happy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">disposition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">seemed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">unite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">blessings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">existence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">nearly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="753f88a37ce94d43bf16521bf9a0b1d9-0" class="displacy" width="7750" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">volume</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">chapter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">i</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">emma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">woodhouse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">handsome</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">clever</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">rich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">comfortable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">home</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">happy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">disposition</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">seemed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">unite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">blessings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">existence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">nearly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo
